# %% [markdown]
# # 🧪 Test Notebook
#
# Just some stuff to verify everything works!

# %%
# Basic Python test
print("Hello from the notebook! 🎉")

# Quick math
x = 42
y = 13
print(f"{x} + {y} = {x + y}")
# Out:
# Hello from the notebook! 🎉
# 42 + 13 = 55

# %%
# Test imports
import pandas as pd
import numpy as np

print(f"pandas version: {pd.__version__}")
print(f"numpy version: {np.__version__}")
# Out:
# pandas version: 2.2.2
# numpy version: 2.0.2

# %%
# Create a small test dataframe
df = pd.DataFrame({
    'name': ['Alice', 'Bob', 'Charlie', 'Diana'],
    'score': [95, 87, 92, 88],
    'passed': [True, True, True, True]
})

df

# %%
# Quick stats
print("Score statistics:")
print(df['score'].describe())

# %%
# Test numpy operations
arr = np.random.randn(5, 3)
print("Random array:")
print(arr)
print(f"\nMean: {arr.mean():.4f}")
print(f"Std: {arr.std():.4f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1238347445.py in <cell line: 0>()
#       1 # Test numpy operations
# ----> 2 arr = np.random.randn(5, 3)
#       3 print("Random array:")
#       4 print(arr)
#       5 print(f"\nMean: {arr.mean():.4f}")
#
# NameError: name 'np' is not defined

# %% [markdown]
# ## ✅ All done!
#
# If you see outputs above, the notebook is working correctly.
